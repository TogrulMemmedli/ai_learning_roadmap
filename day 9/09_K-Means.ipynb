# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# > Unsupervised Learning
#
# > Y=f(X) and we have only X set.
#
# > Clustering, Dimensionality Reduction, Anomaly Detection and Assocation Rules
